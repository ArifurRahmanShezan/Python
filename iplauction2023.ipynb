# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv("D:\\personal\\Data Science\\practice\\iplauction2023.csv")

# %%
df
# Out:
#                 name player style   nationality  base price (in lacs)  \
# 0       Harshit Rana       Bowler         India                   NaN
# 1          Ekant Sen       Batter         India                  20.0
# 2      Wayne Parnell   Allrounder  South Africa                  75.0
# 3    Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4           Joe Root       Batter       England                 100.0
# ..               ...          ...           ...                   ...
# 304         MS Dhoni    WK-Batter         India                   NaN
# 305        Moeen Ali   Allrounder       England                   NaN
# 306  Ruturaj Gaikwad       Batter         India                   NaN
# 307     Rishabh Pant    WK-Batter         India                   NaN
# 308       Axar Patel   Allrounder         India                   NaN
#
#      final price (in lacs) franchise    status
# 0                     20.0       KKR  RETAINED
# ...

# %%
df.nationality=="Bangladesh"
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 304    False
# 305    False
# 306    False
# 307    False
# 308    False
# Name: nationality, Length: 309, dtype: bool

# %%
df[df.nationality=="Bangladesh"]
# Out:
#                   name player style nationality  base price (in lacs)  \
# 3      Shakib Al Hasan   Allrounder  Bangladesh                 150.0
# 25          Litton Das    WK-Batter  Bangladesh                  50.0
# 83        Taskin Ahmed       Bowler  Bangladesh                  50.0
# 191  Mustafizur Rahman       Bowler  Bangladesh                   NaN
#
#      final price (in lacs) franchise    status
# 3                    150.0       KKR      SOLD
# 25                    50.0       KKR      SOLD
# 83                     NaN       NaN    UNSOLD
# 191                  200.0        DC  RETAINED

# %%
df.shape
# Out:
# (309, 7)

# %%
df.columns
# Out:
# Index(['name', 'player style', 'nationality', 'base price (in lacs)',
#        'final price (in lacs)', 'franchise', 'status'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of                 name player style   nationality  base price (in lacs)  \
# 0       Harshit Rana       Bowler         India                   NaN
# 1          Ekant Sen       Batter         India                  20.0
# 2      Wayne Parnell   Allrounder  South Africa                  75.0
# 3    Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4           Joe Root       Batter       England                 100.0
# ..               ...          ...           ...                   ...
# 304         MS Dhoni    WK-Batter         India                   NaN
# 305        Moeen Ali   Allrounder       England                   NaN
# 306  Ruturaj Gaikwad       Batter         India                   NaN
# 307     Rishabh Pant    WK-Batter         India                   NaN
# 308       Axar Patel   Allrounder         India                   NaN
#
#      final price (in lacs) franchise    status
# 0                     20.0       KKR  RETAINED
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   309 non-null    object
#  1   player style           309 non-null    object
#  2   nationality            309 non-null    object
#  3   base price (in lacs)   151 non-null    float64
#  4   final price (in lacs)  238 non-null    float64
#  5   franchise              238 non-null    object
#  6   status                 309 non-null    object
# dtypes: float64(2), object(5)
# memory usage: 17.0+ KB

# %%
df.describe()
# Out:
#        base price (in lacs)  final price (in lacs)
# count            151.000000             238.000000
# mean              59.205298             368.067227
# std               59.688337             449.070117
# min               20.000000              20.000000
# 25%               20.000000              21.250000
# 50%               20.000000             150.000000
# 75%               75.000000             625.000000
# max              200.000000            1850.000000

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                 name player style   nationality  base price (in lacs)  \
# 0       Harshit Rana       Bowler         India                   NaN
# 1          Ekant Sen       Batter         India                  20.0
# 2      Wayne Parnell   Allrounder  South Africa                  75.0
# 3    Shakib Al Hasan   Allrounder    Bangladesh                 150.0
# 4           Joe Root       Batter       England                 100.0
# ..               ...          ...           ...                   ...
# 304         MS Dhoni    WK-Batter         India                   NaN
# 305        Moeen Ali   Allrounder       England                   NaN
# 306  Ruturaj Gaikwad       Batter         India                   NaN
# 307     Rishabh Pant    WK-Batter         India                   NaN
# 308       Axar Patel   Allrounder         India                   NaN
#
#      final price (in lacs) franchise    status
# ...

# %%
df["base price (in lacs)"].fillna(10,inplace =True)
df
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9372\1563301693.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["base price (in lacs)"].fillna(10,inplace =True)
#                 name player style   nationality  base price (in lacs)  \
# 0       Harshit Rana       Bowler         India                  10.0
# 1          Ekant Sen       Batter         India                  20.0
# 2      Wayne Parnell   Allrounder  South Africa                  75.0
# ...

# %%
df["base price (in lacs)"]=df["base price (in lacs)"].astype("int64")

# %%
df
# Out:
#                 name player style   nationality  base price (in lacs)  \
# 0       Harshit Rana       Bowler         India                    10
# 1          Ekant Sen       Batter         India                    20
# 2      Wayne Parnell   Allrounder  South Africa                    75
# 3    Shakib Al Hasan   Allrounder    Bangladesh                   150
# 4           Joe Root       Batter       England                   100
# ..               ...          ...           ...                   ...
# 304         MS Dhoni    WK-Batter         India                    10
# 305        Moeen Ali   Allrounder       England                    10
# 306  Ruturaj Gaikwad       Batter         India                    10
# 307     Rishabh Pant    WK-Batter         India                    10
# 308       Axar Patel   Allrounder         India                    10
#
#      final price (in lacs) franchise    status
# 0                     20.0       KKR  RETAINED
# ...

# %%
df.describe()
# Out:
#        base price (in lacs)  final price (in lacs)
# count            309.000000             238.000000
# mean              34.045307             368.067227
# std               48.394462             449.070117
# min               10.000000              20.000000
# 25%               10.000000              21.250000
# 50%               10.000000             150.000000
# 75%               20.000000             625.000000
# max              200.000000            1850.000000

# %%
df.describe(include=["object"])
# Out:
#               name player style nationality franchise    status
# count          309          309         309       238       309
# unique         309            4          14        10         3
# top     Axar Patel       Bowler       India        RR  RETAINED
# freq             1          111         201        25       158

# %%
df["base price (in lacs)"].value_counts()
# Out:
# base price (in lacs)
# 10     158
# 20      82
# 50      26
# 200     16
# 100     12
# 150      8
# 75       4
# 30       2
# 40       1
# Name: count, dtype: int64

# %%
df["nationality"].value_counts()
# Out:
# nationality
# India           201
# England          24
# South Africa     19
# West Indies      14
# Australia        14
# New Zealand      11
# Sri Lanka         8
# Afghanistan       7
# Bangladesh        4
# Ireland           2
# Zimbabwe          2
# Namibia           1
# Netherlands       1
# Singapore         1
# Name: count, dtype: int64

# %%
df["nationality"].value_counts(normalize=True)
# Out:
# nationality
# India           0.650485
# England         0.077670
# South Africa    0.061489
# West Indies     0.045307
# Australia       0.045307
# New Zealand     0.035599
# Sri Lanka       0.025890
# Afghanistan     0.022654
# Bangladesh      0.012945
# Ireland         0.006472
# Zimbabwe        0.006472
# Namibia         0.003236
# Netherlands     0.003236
# Singapore       0.003236
# Name: proportion, dtype: float64

# %%
df.sort_values(by="final price (in lacs)",ascending=False)
# Out:
#                  name player style   nationality  base price (in lacs)  \
# 150        Sam Curran   Allrounder       England                   200
# 148     Cameron Green   Allrounder     Australia                   200
# 292          KL Rahul    WK-Batter         India                    10
# 147        Ben Stokes   Allrounder       England                   200
# 307      Rishabh Pant    WK-Batter         India                    10
# ..                ...          ...           ...                   ...
# 137  Mujeeb Ur Rahman       Bowler   Afghanistan                   100
# 138    Tabraiz Shamsi       Bowler  South Africa                   100
# 141        Adam Milne       Bowler   New Zealand                   200
# 143      Chris Jordan       Bowler       England                   200
# 145        Tom Banton    WK-Batter       England                   200
#
#      final price (in lacs) franchise    status
# 150                 1850.0      PBKS      SOLD
# ...

# %%
df.sort_values(by=["base price (in lacs)","final price (in lacs)"],ascending=False)
# Out:
#                  name player style  nationality  base price (in lacs)  \
# 150        Sam Curran   Allrounder      England                   200
# 148     Cameron Green   Allrounder    Australia                   200
# 147        Ben Stokes   Allrounder      England                   200
# 136   Nicholas Pooran    WK-Batter  West Indies                   200
# 132      Jason Holder   Allrounder  West Indies                   200
# ..                ...          ...          ...                   ...
# 257  Mohd Arshad Khan       Bowler        India                    10
# 259      Baltej Singh   Allrounder        India                    10
# 263   Hrithik Shokeen   Allrounder        India                    10
# 264      Kuldip Yadav       Bowler        India                    10
# 289        Akash Deep       Bowler        India                    10
#
#      final price (in lacs) franchise    status
# 150                 1850.0      PBKS      SOLD
# ...

# %%
df.sort_values(by=["final price (in lacs)","base price (in lacs)"],ascending=False)
# Out:
#                  name player style  nationality  base price (in lacs)  \
# 150        Sam Curran   Allrounder      England                   200
# 148     Cameron Green   Allrounder    Australia                   200
# 292          KL Rahul    WK-Batter        India                    10
# 147        Ben Stokes   Allrounder      England                   200
# 136   Nicholas Pooran    WK-Batter  West Indies                   200
# ..                ...          ...          ...                   ...
# 121       Priyam Garg       Batter        India                    20
# 123      Himmat Singh       Batter        India                    20
# 125   Rohan Kunnummal       Batter        India                    20
# 126  Shubham Khajuria       Batter        India                    20
# 128        LR Chethan       Batter        India                    20
#
#      final price (in lacs) franchise    status
# 150                 1850.0      PBKS      SOLD
# ...

# %%
df["base price (in lacs)"].mean()
# Out:
# np.float64(34.045307443365694)

# %%
pd.set_option("display.max_rows",400)

# %%
df
# Out:
#                             name player style   nationality  \
# 0                   Harshit Rana       Bowler         India
# 1                      Ekant Sen       Batter         India
# 2                  Wayne Parnell   Allrounder  South Africa
# 3                Shakib Al Hasan   Allrounder    Bangladesh
# 4                       Joe Root       Batter       England
# 5                   Abdul Basith   Allrounder         India
# 6                Prashant Chopra   Allrounder         India
# 7                   Akeal Hosein       Bowler   West Indies
# 8                   Raghav Goyal       Bowler         India
# 9           Yudhvir Singh Charak   Allrounder         India
# 10                     Luke Wood       Bowler       England
# 11            Dilshan Madushanka       Bowler     Sri Lanka
# 12                 Naveen-ul-Haq   Allrounder   Afghanistan
# 13                   Akash Singh       Bowler         India
# 14                 Akash Vashist   Allrounder         India
# ...

# %%
df.sort_values(by=["final price (in lacs)","base price (in lacs)"],ascending=False)
# Out:
#                             name player style   nationality  \
# 150                   Sam Curran   Allrounder       England
# 148                Cameron Green   Allrounder     Australia
# 292                     KL Rahul    WK-Batter         India
# 147                   Ben Stokes   Allrounder       England
# 136              Nicholas Pooran    WK-Batter   West Indies
# 290                 Rohit Sharma       Batter         India
# 296              Ravindra Jadeja   Allrounder         India
# 307                 Rishabh Pant    WK-Batter         India
# 230                 Ishan Kishan    WK-Batter         India
# 282                  Virat Kohli       Batter         India
# 300                  Rashid Khan       Bowler   Afghanistan
# 301                Hardik Pandya   Allrounder         India
# 223                Deepak Chahar       Bowler         India
# 285                 Sanju Samson    WK-Batter         India
# 151                  Harry Brook       Batter       England
# ...

# %%
df.sort_values(by=["final price (in lacs)","base price (in lacs)"],ascending=[False,True])
# Out:
#                             name player style   nationality  \
# 150                   Sam Curran   Allrounder       England
# 148                Cameron Green   Allrounder     Australia
# 292                     KL Rahul    WK-Batter         India
# 147                   Ben Stokes   Allrounder       England
# 290                 Rohit Sharma       Batter         India
# 296              Ravindra Jadeja   Allrounder         India
# 307                 Rishabh Pant    WK-Batter         India
# 136              Nicholas Pooran    WK-Batter   West Indies
# 230                 Ishan Kishan    WK-Batter         India
# 282                  Virat Kohli       Batter         India
# 300                  Rashid Khan       Bowler   Afghanistan
# 301                Hardik Pandya   Allrounder         India
# 223                Deepak Chahar       Bowler         India
# 285                 Sanju Samson    WK-Batter         India
# 151                  Harry Brook       Batter       England
# ...

# %%
df.replace({"SOLD":1,"UNSOLD":0,"RETAINED":2})
# Out:
#                             name player style   nationality  \
# 0                   Harshit Rana       Bowler         India
# 1                      Ekant Sen       Batter         India
# 2                  Wayne Parnell   Allrounder  South Africa
# 3                Shakib Al Hasan   Allrounder    Bangladesh
# 4                       Joe Root       Batter       England
# 5                   Abdul Basith   Allrounder         India
# 6                Prashant Chopra   Allrounder         India
# 7                   Akeal Hosein       Bowler   West Indies
# 8                   Raghav Goyal       Bowler         India
# 9           Yudhvir Singh Charak   Allrounder         India
# 10                     Luke Wood       Bowler       England
# 11            Dilshan Madushanka       Bowler     Sri Lanka
# 12                 Naveen-ul-Haq   Allrounder   Afghanistan
# 13                   Akash Singh       Bowler         India
# 14                 Akash Vashist   Allrounder         India
# ...

# %%
df
# Out:
#                             name player style   nationality  \
# 0                   Harshit Rana       Bowler         India
# 1                      Ekant Sen       Batter         India
# 2                  Wayne Parnell   Allrounder  South Africa
# 3                Shakib Al Hasan   Allrounder    Bangladesh
# 4                       Joe Root       Batter       England
# 5                   Abdul Basith   Allrounder         India
# 6                Prashant Chopra   Allrounder         India
# 7                   Akeal Hosein       Bowler   West Indies
# 8                   Raghav Goyal       Bowler         India
# 9           Yudhvir Singh Charak   Allrounder         India
# 10                     Luke Wood       Bowler       England
# 11            Dilshan Madushanka       Bowler     Sri Lanka
# 12                 Naveen-ul-Haq   Allrounder   Afghanistan
# 13                   Akash Singh       Bowler         India
# 14                 Akash Vashist   Allrounder         India
# ...

# %%
df[df["status"] == 1]["final price (in lacs)"].mean()
# Out:
# np.float64(208.75)

# %%
df[(df["status"]=="SOLD") &(df["nationality"]=="England")]["base price (in lacs)"].max()
# Out:
# nan

# %%
df[(df["status"] == 1) & (df["nationality"] == "England")]["base price (in lacs)"].max()
# Out:
# np.int64(200)

# %%
df.loc[0:5,"name":"base price (in lacs)"]
# Out:
#               name player style   nationality  base price (in lacs)
# 0     Harshit Rana       Bowler         India                    10
# 1        Ekant Sen       Batter         India                    20
# 2    Wayne Parnell   Allrounder  South Africa                    75
# 3  Shakib Al Hasan   Allrounder    Bangladesh                   150
# 4         Joe Root       Batter       England                   100
# 5     Abdul Basith   Allrounder         India                    20

# %%
df.iloc[0:5,0:5]
# Out:
#               name player style   nationality  base price (in lacs)  \
# 0     Harshit Rana       Bowler         India                    10
# 1        Ekant Sen       Batter         India                    20
# 2    Wayne Parnell   Allrounder  South Africa                    75
# 3  Shakib Al Hasan   Allrounder    Bangladesh                   150
# 4         Joe Root       Batter       England                   100
#
#    final price (in lacs)
# 0                   20.0
# 1                    NaN
# 2                    NaN
# 3                  150.0
# 4                  100.0

# %%
df[-1:]
# Out:
#            name player style nationality  base price (in lacs)  \
# 308  Axar Patel   Allrounder       India                    10
#
#      final price (in lacs) franchise  status
# 308                  900.0        DC       2

# %%
df.select_dtypes(include=np.number).apply(np.max, axis=1)
# Out:
# 0        20.0
# 1        20.0
# 2        75.0
# 3       150.0
# 4       100.0
# 5        20.0
# 6        20.0
# 7       100.0
# 8        20.0
# 9        20.0
# 10      100.0
# 11       50.0
# 12       50.0
# 13       20.0
# 14       20.0
# 15       20.0
# 16       50.0
# 17      200.0
# 18       50.0
# 19       20.0
# 20       30.0
# 21       20.0
# 22       20.0
# 23      150.0
# 24       50.0
# 25       50.0
# 26      460.0
# 27       20.0
# 28       20.0
# 29       20.0
# 30       20.0
# 31       20.0
# 32       20.0
# 33       20.0
# 34       20.0
# 35       20.0
# 36       20.0
# 37       20.0
# 38       20.0
# 39       20.0
# 40       20.0
# 41       20.0
# 42       20.0
# 43       20.0
# 44       50.0
# 45       75.0
# 46       50.0
# 47       60.0
# 48       20.0
# 49       20.0
# 50       20.0
# 51      100.0
# 52       20.0
# 53       20.0
# 54       20.0
# 55       20.0
# 56       50.0
# 57      440.0
# 58       50.0
# 59      200.0
# 60       20.0
# 61       20.0
# ...

# %%
df.select_dtypes(include=np.number).apply(np.max)
# Out:
# base price (in lacs)      200.0
# final price (in lacs)    1850.0
# status                      2.0
# dtype: float64

# %%
df_numeric = df.apply(pd.to_numeric, errors='coerce')
df_numeric.apply(np.max)
# Out:
# name                        NaN
# player style                NaN
# nationality                 NaN
# base price (in lacs)      200.0
# final price (in lacs)    1850.0
# franchise                   NaN
# status                      2.0
# dtype: float64

# %%
df[df["name"].apply(lambda name:name[0]=="S")]
# Out:
#                     name player style  nationality  base price (in lacs)  \
# 3        Shakib Al Hasan   Allrounder   Bangladesh                   150
# 15       Suryansh Shedge   Allrounder        India                    20
# 27          Shivam Singh   Allrounder        India                    20
# 31        Shubhang Hegde   Allrounder        India                    20
# 32            Sonu Yadav   Allrounder        India                    20
# 35         Shubham Kapse       Bowler        India                    20
# 42      Sanjay Raghunath       Batter        India                    20
# 50          Sanjay Yadav   Allrounder        India                    20
# 52          Sumeet Verma   Allrounder        India                    20
# 53         Swapnil Singh   Allrounder        India                    20
# 54          Shams Mulani   Allrounder        India                    20
# 60         Suyash Sharma       Bowler        India                    20
# ...

# %%
d = {0: "UNSOLD", 1: "SOLD",2:"RETAINED"}
df["status"] = df["status"].map(d)
#df.head()

# %%
df
# Out:
#                             name player style   nationality  \
# 0                   Harshit Rana       Bowler         India
# 1                      Ekant Sen       Batter         India
# 2                  Wayne Parnell   Allrounder  South Africa
# 3                Shakib Al Hasan   Allrounder    Bangladesh
# 4                       Joe Root       Batter       England
# 5                   Abdul Basith   Allrounder         India
# 6                Prashant Chopra   Allrounder         India
# 7                   Akeal Hosein       Bowler   West Indies
# 8                   Raghav Goyal       Bowler         India
# 9           Yudhvir Singh Charak   Allrounder         India
# 10                     Luke Wood       Bowler       England
# 11            Dilshan Madushanka       Bowler     Sri Lanka
# 12                 Naveen-ul-Haq   Allrounder   Afghanistan
# 13                   Akash Singh       Bowler         India
# 14                 Akash Vashist   Allrounder         India
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   name                   309 non-null    object
#  1   player style           309 non-null    object
#  2   nationality            309 non-null    object
#  3   base price (in lacs)   309 non-null    int64
#  4   final price (in lacs)  238 non-null    float64
#  5   franchise              238 non-null    object
#  6   status                 309 non-null    object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 17.0+ KB

# %%
columns_to_show=["base price (in lacs)","final price (in lacs)"]
df.groupby(["status"])[columns_to_show].describe(percentiles=[])
# Out:
#          base price (in lacs)                                                 \
#                         count       mean        std   min   25%   50%    75%
# status
# RETAINED                158.0  10.000000   0.000000  10.0  10.0  10.0   10.0
# SOLD                     80.0  62.375000  61.252616  20.0  20.0  20.0  100.0
# UNSOLD                   71.0  55.633803  58.100465  20.0  20.0  20.0   50.0
#
#                 final price (in lacs)                                      \
#             max                 count        mean         std   min   25%
# status
# RETAINED   10.0                 158.0  448.734177  450.104000  20.0  50.0
# SOLD      200.0                  80.0  208.750000  404.538728  20.0  20.0
# UNSOLD    200.0                   0.0         NaN         NaN   NaN   NaN
#
#
#             50%     75%     max
# status
# RETAINED  300.0  793.75  1700.0
# SOLD       50.0  157.50  1850.0
# UNSOLD      NaN     NaN     NaN

# %%
columns_to_show=["base price (in lacs)","final price (in lacs)"]
df.groupby(["status"])[columns_to_show].agg([np.max,np.min])
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9372\1716730429.py:2: FutureWarning: The provided callable <function max at 0x000001DF6EA09F80> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   df.groupby(["status"])[columns_to_show].agg([np.max,np.min])
# C:\Users\User\AppData\Local\Temp\ipykernel_9372\1716730429.py:2: FutureWarning: The provided callable <function min at 0x000001DF6EA0A0C0> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   df.groupby(["status"])[columns_to_show].agg([np.max,np.min])
# ...

# %%
pd.crosstab(df["status"],df["player style"])
# Out:
# player style  Allrounder  Batter  Bowler  WK-Batter
# status
# RETAINED              45      32      62         19
# SOLD                  32      12      25         11
# UNSOLD                26      11      24         10

# %%
pd.crosstab(df["status"],df["player style"],normalize=True)
# Out:
# player style  Allrounder    Batter    Bowler  WK-Batter
# status
# RETAINED        0.145631  0.103560  0.200647   0.061489
# SOLD            0.103560  0.038835  0.080906   0.035599
# UNSOLD          0.084142  0.035599  0.077670   0.032362

# %%
df.pivot_table(
    ["base price (in lacs)","final price (in lacs)"],
    ["franchise"],
    aggfunc="max"
)
# Out:
#            base price (in lacs)  final price (in lacs)
# franchise
# CSK                         200                 1625.0
# DC                          200                 1600.0
# GT                          200                 1500.0
# KKR                         150                 1225.0
# LSG                         200                 1700.0
# MI                          200                 1750.0
# PBKS                        200                 1850.0
# RCB                         150                 1500.0
# RR                          200                 1400.0
# SRH                         200                 1325.0

# %%
df.pivot_table(
    ["base price (in lacs)","final price (in lacs)"],
    ["player style"],
    aggfunc="max"
)
# Out:
#               base price (in lacs)  final price (in lacs)
# player style
# Allrounder                     200                 1850.0
# Batter                         200                 1600.0
# Bowler                         200                 1500.0
# WK-Batter                      200                 1700.0

# %%
df.replace(np.nan,0,inplace=True)

# %%
df
# Out:
#                             name player style   nationality  \
# 0                   Harshit Rana       Bowler         India
# 1                      Ekant Sen       Batter         India
# 2                  Wayne Parnell   Allrounder  South Africa
# 3                Shakib Al Hasan   Allrounder    Bangladesh
# 4                       Joe Root       Batter       England
# 5                   Abdul Basith   Allrounder         India
# 6                Prashant Chopra   Allrounder         India
# 7                   Akeal Hosein       Bowler   West Indies
# 8                   Raghav Goyal       Bowler         India
# 9           Yudhvir Singh Charak   Allrounder         India
# 10                     Luke Wood       Bowler       England
# 11            Dilshan Madushanka       Bowler     Sri Lanka
# 12                 Naveen-ul-Haq   Allrounder   Afghanistan
# 13                   Akash Singh       Bowler         India
# 14                 Akash Vashist   Allrounder         India
# ...

# %%
difference=(
    df["final price (in lacs)"]
    -df["base price (in lacs)"]
)

df.insert(loc=len(df.columns), column="difference", value=difference)

# %%
df
# Out:
#                             name player style   nationality  \
# 0                   Harshit Rana       Bowler         India
# 1                      Ekant Sen       Batter         India
# 2                  Wayne Parnell   Allrounder  South Africa
# 3                Shakib Al Hasan   Allrounder    Bangladesh
# 4                       Joe Root       Batter       England
# 5                   Abdul Basith   Allrounder         India
# 6                Prashant Chopra   Allrounder         India
# 7                   Akeal Hosein       Bowler   West Indies
# 8                   Raghav Goyal       Bowler         India
# 9           Yudhvir Singh Charak   Allrounder         India
# 10                     Luke Wood       Bowler       England
# 11            Dilshan Madushanka       Bowler     Sri Lanka
# 12                 Naveen-ul-Haq   Allrounder   Afghanistan
# 13                   Akash Singh       Bowler         India
# 14                 Akash Vashist   Allrounder         India
# ...

# %%
df.drop(["difference"],axis=1,inplace=True)

# %%
df
# Out:
#                             name player style   nationality  \
# 0                   Harshit Rana       Bowler         India
# 1                      Ekant Sen       Batter         India
# 2                  Wayne Parnell   Allrounder  South Africa
# 3                Shakib Al Hasan   Allrounder    Bangladesh
# 4                       Joe Root       Batter       England
# 5                   Abdul Basith   Allrounder         India
# 6                Prashant Chopra   Allrounder         India
# 7                   Akeal Hosein       Bowler   West Indies
# 8                   Raghav Goyal       Bowler         India
# 9           Yudhvir Singh Charak   Allrounder         India
# 10                     Luke Wood       Bowler       England
# 11            Dilshan Madushanka       Bowler     Sri Lanka
# 12                 Naveen-ul-Haq   Allrounder   Afghanistan
# 13                   Akash Singh       Bowler         India
# 14                 Akash Vashist   Allrounder         India
# ...

# %%
df.drop([3])
# Out:
#                             name player style   nationality  \
# 0                   Harshit Rana       Bowler         India
# 1                      Ekant Sen       Batter         India
# 2                  Wayne Parnell   Allrounder  South Africa
# 4                       Joe Root       Batter       England
# 5                   Abdul Basith   Allrounder         India
# 6                Prashant Chopra   Allrounder         India
# 7                   Akeal Hosein       Bowler   West Indies
# 8                   Raghav Goyal       Bowler         India
# 9           Yudhvir Singh Charak   Allrounder         India
# 10                     Luke Wood       Bowler       England
# 11            Dilshan Madushanka       Bowler     Sri Lanka
# 12                 Naveen-ul-Haq   Allrounder   Afghanistan
# 13                   Akash Singh       Bowler         India
# 14                 Akash Vashist   Allrounder         India
# 15               Suryansh Shedge   Allrounder         India
# ...

# %%
pd.crosstab(df["status"], df["player style"], margins=True)
# Out:
# player style  Allrounder  Batter  Bowler  WK-Batter  All
# status
# RETAINED              45      32      62         19  158
# SOLD                  32      12      25         11   80
# UNSOLD                26      11      24         10   71
# All                  103      55     111         40  309

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(x="player style", hue="status", data=df);

# %%
pd.crosstab(df["status"],df["player style"],margins=True)
# Out:
# player style  Allrounder  Batter  Bowler  WK-Batter  All
# status
# RETAINED              45      32      62         19  158
# SOLD                  32      12      25         11   80
# UNSOLD                26      11      24         10   71
# All                  103      55     111         40  309

# %%
sns.countplot(x="player style",hue="franchise",data=df)
# Out:
# <Axes: xlabel='player style', ylabel='count'>

# %%
status_counts = df['status'].value_counts()
plt.figure(figsize=(10, 6))
plt.pie(status_counts, labels=status_counts.index, autopct='%0.001f%%', startangle=30)
plt.title('Player Status')
plt.show()
