# %%
import pandas as pd

# %%
df=pd.read_csv("D:\\personal\\Data Science\\3_read_write_to_excel\\stock_data.csv")

# %%
df=pd.read_csv("D:\\personal\\Data Science\\3_read_write_to_excel\\stock_data.csv",skiprows=1)

# %%
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df=pd.read_csv("D:\\personal\\Data Science\\3_read_write_to_excel\\stock_data.csv",header=1)
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df=pd.read_csv("D:\\personal\\Data Science\\3_read_write_to_excel\\stock_data.csv",names =["stock_symbol","eps","revenue","price","people"])

# %%
df
# Out:
#                  stock_symbol            eps  revenue  price         people
# 0  Datasource: Google finance            NaN      NaN    NaN            NaN
# 1                     tickers            eps  revenue  price         people
# 2                       GOOGL          27.82       87    845     larry page
# 3                         WMT           4.61      484     65           n.a.
# 4                        MSFT             -1       85     64     bill gates
# 5                        RIL   not available       50   1023  mukesh ambani
# 6                        TATA            5.6       -1   n.a.     ratan tata

# %%
df=pd.read_csv("D:\\personal\\Data Science\\3_read_write_to_excel\\stock_data.csv",nrows=5)

# %%
df
# Out:
#   Datasource: Google finance     Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                    tickers            eps    revenue      price
# 1                      GOOGL          27.82         87        845
# 2                        WMT           4.61        484         65
# 3                       MSFT             -1         85         64
# 4                       RIL   not available         50       1023
#
#       Unnamed: 4
# 0         people
# 1     larry page
# 2           n.a.
# 3     bill gates
# 4  mukesh ambani

# %%
df=pd.read_csv("D:\\personal\\Data Science\\3_read_write_to_excel\\stock_data.csv",header=1,nrows=5)

# %%
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df=pd.read_csv("D:\\personal\\Data Science\\3_read_write_to_excel\\stock_data.csv",header=1,nrows=5,names=["stock_symbol","eps","revenue","price","people"])

# %%
df
# Out:
#   stock_symbol            eps  revenue price         people
# 0        GOOGL          27.82       87   845     larry page
# 1          WMT           4.61      484    65           n.a.
# 2         MSFT             -1       85    64     bill gates
# 3         RIL   not available       50  1023  mukesh ambani
# 4         TATA            5.6       -1  n.a.     ratan tata

# %%
df=pd.read_csv("D:\\personal\\Data Science\\3_read_write_to_excel\\stock_data.csv",header=1,nrows=5,names=["stock_symbol","eps","revenue","price","people"],na_values={
    "eps":["nort available"],
    "revenue":["-1"]
})

# %%
df
# Out:
#   stock_symbol            eps  revenue price         people
# 0        GOOGL          27.82     87.0   845     larry page
# 1          WMT           4.61    484.0    65           n.a.
# 2         MSFT             -1     85.0    64     bill gates
# 3         RIL   not available     50.0  1023  mukesh ambani
# 4         TATA            5.6      NaN  n.a.     ratan tata

# %%
import pandas as pd
df=pd.read_csv("D:\\personal\\Data Science\\3_read_write_to_excel\\stock_data.csv",header=1,nrows=5,names=["stock_symbol","eps","revenue","price","people"],na_values=["not available","n.a.",-1])

# %%
df
# Out:
#   stock_symbol    eps  revenue   price         people
# 0        GOOGL  27.82     87.0   845.0     larry page
# 1          WMT   4.61    484.0    65.0            NaN
# 2         MSFT    NaN     85.0    64.0     bill gates
# 3         RIL     NaN     50.0  1023.0  mukesh ambani
# 4         TATA   5.60      NaN     NaN     ratan tata

# %%
df
# Out:
#   stock_symbol    eps  revenue   price         people
# 0        GOOGL  27.82     87.0   845.0     larry page
# 1          WMT   4.61    484.0    65.0            NaN
# 2         MSFT    NaN     85.0    64.0     bill gates
# 3         RIL     NaN     50.0  1023.0  mukesh ambani
# 4         TATA   5.60      NaN     NaN     ratan tata

# %%
df["pe"]=df["price"]/df["eps"]

# %%
df
# Out:
#   stock_symbol    eps  revenue   price         people         pe
# 0        GOOGL  27.82     87.0   845.0     larry page  30.373832
# 1          WMT   4.61    484.0    65.0            NaN  14.099783
# 2         MSFT    NaN     85.0    64.0     bill gates        NaN
# 3         RIL     NaN     50.0  1023.0  mukesh ambani        NaN
# 4         TATA   5.60      NaN     NaN     ratan tata        NaN

# %%
df.to_csv("D:\\personal\\Data Science\\3_read_write_to_excel\\pe.csv")

# %%
df
# Out:
#   stock_symbol    eps  revenue   price         people         pe
# 0        GOOGL  27.82     87.0   845.0     larry page  30.373832
# 1          WMT   4.61    484.0    65.0            NaN  14.099783
# 2         MSFT    NaN     85.0    64.0     bill gates        NaN
# 3         RIL     NaN     50.0  1023.0  mukesh ambani        NaN
# 4         TATA   5.60      NaN     NaN     ratan tata        NaN

# %%
df.to_csv("D:\\personal\\Data Science\\3_read_write_to_excel\\pe.csv",index=False)

# %%
df
# Out:
#   stock_symbol    eps  revenue   price         people         pe
# 0        GOOGL  27.82     87.0   845.0     larry page  30.373832
# 1          WMT   4.61    484.0    65.0            NaN  14.099783
# 2         MSFT    NaN     85.0    64.0     bill gates        NaN
# 3         RIL     NaN     50.0  1023.0  mukesh ambani        NaN
# 4         TATA   5.60      NaN     NaN     ratan tata        NaN

# %%
df
# Out:
#   stock_symbol    eps  revenue   price         people         pe
# 0        GOOGL  27.82     87.0   845.0     larry page  30.373832
# 1          WMT   4.61    484.0    65.0            NaN  14.099783
# 2         MSFT    NaN     85.0    64.0     bill gates        NaN
# 3         RIL     NaN     50.0  1023.0  mukesh ambani        NaN
# 4         TATA   5.60      NaN     NaN     ratan tata        NaN

# %%
df_movies=pd.read_excel("D:\\personal\\Data Science\\3_read_write_to_excel\\movies_db.xlsx","movies")

# %%
df_movies
# Out:
#     movie_id                                        title   industry  \
# 0        101                             K.G.F: Chapter 2  Bollywood
# 1        102  Doctor Strange in the Multiverse of Madness  Hollywood
# 2        103                        Thor: The Dark World   Hollywood
# 3        104                              Thor: Ragnarok   Hollywood
# 4        105                      Thor: Love and Thunder   Hollywood
# 5        106                                       Sholay  Bollywood
# 6        107                  Dilwale Dulhania Le Jayenge  Bollywood
# 7        108                                     3 Idiots  Bollywood
# 8        109                     Kabhi Khushi Kabhie Gham  Bollywood
# 9        110                             Bajirao Mastani   Bollywood
# 10       111                     The Shawshank Redemption  Hollywood
# 11       112                                    Inception  Hollywood
# 12       113                                 Interstellar  Hollywood
# ...

# %%
df_financials=pd.read_excel("D:\\personal\\Data Science\\3_read_write_to_excel\\movies_db.xlsx","financials")

# %%
df_financials
# Out:
#     movie_id    budget   revenue       unit currency
# 0        101      1.00      12.5   Billions      INR
# 1        102    200.00     954.8   Millions      USD
# 2        103    165.00     644.8   Millions       $$
# 3        104    180.00     854.0   Millions  Dollars
# 4        105    250.00     670.0   Millions      USD
# 5        107    400.00    2000.0   Millions      INR
# 6        108    550.00    4000.0   Millions      INR
# 7        109    390.00    1360.0   Millions      INR
# 8        110      1.40       3.5   Billions      INR
# 9        111     25.00      73.3   Millions      USD
# 10       113    165.00     701.8   Millions      USD
# 11       114    205.00     365.3   Millions      USD
# 12       115     55.00     307.1   Millions      USD
# 13       116    103.00     460.5   Millions      USD
# 14       117    200.00    2202.0   Millions      USD
# 15       118      3.18       3.3   Millions      USD
# 16       119    237.00    2847.0   Millions      USD
# ...

# %%
df_movies=pd.read_excel("D:\\personal\\Data Science\\3_read_write_to_excel\\movies_db.xlsx","actors")
df_movies
# Out:
#     actor_id                  name  birth_year
# 0         50                  Yash        1986
# 1         51           Sanjay Dutt        1959
# 2         52  Benedict Cumberbatch        1976
# 3         53       Elizabeth Olsen        1989
# 4         54       Chris Hemsworth        1983
# ..       ...                   ...         ...
# 62       166       Tommy Lee Jones        1946
# 63       167        Sebastian Stan        1982
# 64       168           Anil Kapoor        1956
# 65       169     Sidharth Malhotra        1985
# 66       170          Kiara Advani        1991
#
# [67 rows x 3 columns]

# %%
df_movie_actor=pd.read_excel("D:\\personal\\Data Science\\3_read_write_to_excel\\movies_db.xlsx","movie_actor")
df_movie_actor
# Out:
#     movie_id  actor_id
# 0        101        50
# 1        101        51
# 2        102        52
# 3        102        53
# 4        103        54
# ..       ...       ...
# 80       138       167
# 81       139       164
# 82       139       168
# 83       140       169
# 84       140       170
#
# [85 rows x 2 columns]

# %%
df_languages=pd.read_excel("D:\\personal\\Data Science\\3_read_write_to_excel\\movies_db.xlsx","languages")
df_languages
# Out:
#    language_id      name
# 0            1     Hindi
# 1            2    Telugu
# 2            3   Kannada
# 3            4     Tamil
# 4            5   English
# 5            6    French
# 6            7   Bengali
# 7            8  Gujarati

# %%
def standardize_currency(curr):
    if (curr=="$$" or curr=="Dollars"):
       return "USD"
    return curr

df_financials=pd.read_excel("D:\\personal\\Data Science\\3_read_write_to_excel\\movies_db.xlsx","financials",converters={
    "currency": standardize_currency
})
df_financials
# Out:
#     movie_id    budget   revenue       unit currency
# 0        101      1.00      12.5   Billions      INR
# 1        102    200.00     954.8   Millions      USD
# 2        103    165.00     644.8   Millions      USD
# 3        104    180.00     854.0   Millions      USD
# 4        105    250.00     670.0   Millions      USD
# 5        107    400.00    2000.0   Millions      INR
# 6        108    550.00    4000.0   Millions      INR
# 7        109    390.00    1360.0   Millions      INR
# 8        110      1.40       3.5   Billions      INR
# 9        111     25.00      73.3   Millions      USD
# 10       113    165.00     701.8   Millions      USD
# 11       114    205.00     365.3   Millions      USD
# 12       115     55.00     307.1   Millions      USD
# 13       116    103.00     460.5   Millions      USD
# 14       117    200.00    2202.0   Millions      USD
# 15       118      3.18       3.3   Millions      USD
# 16       119    237.00    2847.0   Millions      USD
# ...

# %%
pd.merge(df_movies,df_financials,on= "movie_id")
# Out:
#     movie_id                                        title   industry  \
# 0        101                             K.G.F: Chapter 2  Bollywood
# 1        102  Doctor Strange in the Multiverse of Madness  Hollywood
# 2        103                        Thor: The Dark World   Hollywood
# 3        104                              Thor: Ragnarok   Hollywood
# 4        105                      Thor: Love and Thunder   Hollywood
# 5        107                  Dilwale Dulhania Le Jayenge  Bollywood
# 6        108                                     3 Idiots  Bollywood
# 7        109                     Kabhi Khushi Kabhie Gham  Bollywood
# 8        110                             Bajirao Mastani   Bollywood
# 9        111                     The Shawshank Redemption  Hollywood
# 10       113                                 Interstellar  Hollywood
# 11       115                     The Pursuit of Happyness  Hollywood
# 12       116                                    Gladiator  Hollywood
# ...

# %%
df_merged= pd.merge(df_movies,df_financials,on= "movie_id")

# %%
df_merged
# Out:
#     movie_id                                        title   industry  \
# 0        101                             K.G.F: Chapter 2  Bollywood
# 1        102  Doctor Strange in the Multiverse of Madness  Hollywood
# 2        103                        Thor: The Dark World   Hollywood
# 3        104                              Thor: Ragnarok   Hollywood
# 4        105                      Thor: Love and Thunder   Hollywood
# 5        107                  Dilwale Dulhania Le Jayenge  Bollywood
# 6        108                                     3 Idiots  Bollywood
# 7        109                     Kabhi Khushi Kabhie Gham  Bollywood
# 8        110                             Bajirao Mastani   Bollywood
# 9        111                     The Shawshank Redemption  Hollywood
# 10       113                                 Interstellar  Hollywood
# 11       115                     The Pursuit of Happyness  Hollywood
# 12       116                                    Gladiator  Hollywood
# ...

# %%
df_merged.to_excel("D:\\personal\\Data Science\\3_read_write_to_excel\\merged_db.xlsx",sheet_name="merged",index=False)

# %%
df_stocks=pd.DataFrame({
    'tickers': ['GOOGL', 'WMT', 'MSFT'],
    'price': [845, 65, 64 ],
    'pe': [30.37, 14.26, 30.97],
    'eps': [27.82, 4.61, 2.12]
})

# %%
df_weather=pd.DataFrame({
    'day': ['1/1/2017','1/2/2017','1/3/2017'],
    'temperature': [32,35,28],
    'event': ['Rain', 'Sunny', 'Snow']  
})

# %%
df_stocks
# Out:
#   tickers  price     pe    eps
# 0   GOOGL    845  30.37  27.82
# 1     WMT     65  14.26   4.61
# 2    MSFT     64  30.97   2.12

# %%
df_weather
# Out:
#         day  temperature  event
# 0  1/1/2017           32   Rain
# 1  1/2/2017           35  Sunny
# 2  1/3/2017           28   Snow

# %%
with pd.ExcelWriter("D:\\personal\\Data Science\\3_read_write_to_excel\\stocks_weathernew.xlsx") as writer:
    df_stocks.to_excel(writer,sheet_name="stocks")
    df_weather.to_excel(writer,sheet_name="weather")

# %%
import pandas as pd

# %%
df= pd.read_csv("D:\\personal\\Data Science\\3_read_write_to_excel\\Exercises\\movies_data.csv")

# %%
df
# Out:
#     movie_id                                        title   industry language  \
# 0        101                             K.G.F: Chapter 2  Bollywood  Kannada
# 1        102  Doctor Strange in the Multiverse of Madness  Hollywood  English
# 2        103                        Thor: The Dark World   Hollywood  English
# 3        104                              Thor: Ragnarok   Hollywood  English
# 4        105                      Thor: Love and Thunder   Hollywood  English
# 5        111                     The Shawshank Redemption  Hollywood  English
# 6        113                                 Interstellar  Hollywood  English
# 7        115                     The Pursuit of Happyness  Hollywood  English
# 8        116                                    Gladiator  Hollywood  English
# 9        117                                      Titanic  Hollywood  English
# 10       118                        It's a Wonderful Life  Hollywood  English
# ...

# %%
df.head(5)
# Out:
#    movie_id                                        title   industry language  \
# 0       101                             K.G.F: Chapter 2  Bollywood  Kannada
# 1       102  Doctor Strange in the Multiverse of Madness  Hollywood  English
# 2       103                        Thor: The Dark World   Hollywood  English
# 3       104                              Thor: Ragnarok   Hollywood  English
# 4       105                      Thor: Love and Thunder   Hollywood  English
#
#    release_year  imdb_rating          studio  budget  revenue      unit  \
# 0          2022          8.4   Hombale Films     1.0     12.5  Billions
# 1          2022          7.0  Marvel Studios   200.0    954.8  Millions
# 2          2013          6.8  Marvel Studios   165.0    644.8  Millions
# 3          2017          7.9  Marvel Studios   180.0    854.0  Millions
# 4          2022          6.8  Marvel Studios   250.0    670.0  Millions
#
#   currency
# 0      INR
# 1      USD
# 2      USD
# 3      USD
# ...

# %%
df["year_classify"]=df["release_year"].apply(lambda x: "before 2000"if x<2000 else "From 2000")
df
# Out:
#     movie_id                                        title   industry language  \
# 0        101                             K.G.F: Chapter 2  Bollywood  Kannada
# 1        102  Doctor Strange in the Multiverse of Madness  Hollywood  English
# 2        103                        Thor: The Dark World   Hollywood  English
# 3        104                              Thor: Ragnarok   Hollywood  English
# 4        105                      Thor: Love and Thunder   Hollywood  English
# 5        111                     The Shawshank Redemption  Hollywood  English
# 6        113                                 Interstellar  Hollywood  English
# 7        115                     The Pursuit of Happyness  Hollywood  English
# 8        116                                    Gladiator  Hollywood  English
# 9        117                                      Titanic  Hollywood  English
# 10       118                        It's a Wonderful Life  Hollywood  English
# ...

# %%
df.to_csv("D:\\personal\\Data Science\\3_read_write_to_excel\\Exercises\\final_movie_data.csv",columns=["movie_id","title","budget","revenue","year_classify"],index=False)

# %%
df
# Out:
#     movie_id                                        title   industry language  \
# 0        101                             K.G.F: Chapter 2  Bollywood  Kannada
# 1        102  Doctor Strange in the Multiverse of Madness  Hollywood  English
# 2        103                        Thor: The Dark World   Hollywood  English
# 3        104                              Thor: Ragnarok   Hollywood  English
# 4        105                      Thor: Love and Thunder   Hollywood  English
# 5        111                     The Shawshank Redemption  Hollywood  English
# 6        113                                 Interstellar  Hollywood  English
# 7        115                     The Pursuit of Happyness  Hollywood  English
# 8        116                                    Gladiator  Hollywood  English
# 9        117                                      Titanic  Hollywood  English
# 10       118                        It's a Wonderful Life  Hollywood  English
# ...
