# %%
import pandas as pd

# %%
india_weather =pd.DataFrame({
    "city":["mumbi","delhi","bangalore"],
    "temperature":[32,45,30],
    "humidity":[80,60,78]
})
india_weather
# Out:
#         city  temperature  humidity
# 0      mumbi           32        80
# 1      delhi           45        60
# 2  bangalore           30        78

# %%
us_weather=pd.DataFrame({
    "city":["new york","chicago","orlando"],
    "temperature":[21,14,35],
    "humidity":[68,65,75]
})
us_weather
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
df=pd.concat([india_weather,us_weather])

# %%
df
# Out:
#         city  temperature  humidity
# 0      mumbi           32        80
# 1      delhi           45        60
# 2  bangalore           30        78
# 0   new york           21        68
# 1    chicago           14        65
# 2    orlando           35        75

# %%
df=pd.concat([india_weather,us_weather],keys=["india","us"])

# %%
df
# Out:
#               city  temperature  humidity
# india 0      mumbi           32        80
#       1      delhi           45        60
#       2  bangalore           30        78
# us    0   new york           21        68
#       1    chicago           14        65
#       2    orlando           35        75

# %%
df=pd.concat([india_weather,us_weather])

# %%
df
# Out:
#         city  temperature  humidity
# 0      mumbi           32        80
# 1      delhi           45        60
# 2  bangalore           30        78
# 0   new york           21        68
# 1    chicago           14        65
# 2    orlando           35        75

# %%
df=pd.concat([india_weather,us_weather],ignore_index=True)

# %%
df
# Out:
#         city  temperature  humidity
# 0      mumbi           32        80
# 1      delhi           45        60
# 2  bangalore           30        78
# 3   new york           21        68
# 4    chicago           14        65
# 5    orlando           35        75

# %%
df.loc["india"]
# Out:
#         city  temperature  humidity
# 0      mumbi           32        80
# 1      delhi           45        60
# 2  bangalore           30        78

# %%
temperature_df=pd.DataFrame({
    "city":["mumbi","delhi","bangalore"],
    "temeperature":[32,45,30]
})
temperature_df
# Out:
#         city  temeperature
# 0      mumbi            32
# 1      delhi            45
# 2  bangalore            30

# %%
windspeed_df=pd.DataFrame({
    "city":["mumbi","delhi"],
    "temeperature":[7,12]
})
windspeed_df
# Out:
#     city  temeperature
# 0  mumbi             7
# 1  delhi            12

# %%
pd.concat([temperature_df,windspeed_df],axis=1)
# Out:
#         city  temeperature   city  temeperature
# 0      mumbi            32  mumbi           7.0
# 1      delhi            45  delhi          12.0
# 2  bangalore            30    NaN           NaN

# %%
import pandas as pd

# %%
df1=pd.DataFrame({
    "city":["new york","chicago","orlando"],
    "temperature":[21,14,35]
})
df1
# Out:
#        city  temperature
# 0  new york           21
# 1   chicago           14
# 2   orlando           35

# %%
df2=pd.DataFrame({
    "city":["chicago","new york","orlando"],
    "humidity":[65,68,75]
})
df2
# Out:
#        city  humidity
# 0   chicago        65
# 1  new york        68
# 2   orlando        75

# %%
pd.merge(df1,df2,on="city")
# Out:
#        city  temperature  humidity
# 0  new york           21        68
# 1   chicago           14        65
# 2   orlando           35        75

# %%
import pandas as pd
df1=pd.DataFrame({
    "city":["chicago","new york","orlando","baltimore"],
    "temperature":[21,14,35,38]
})
df1
# Out:
#         city  temperature
# 0    chicago           21
# 1   new york           14
# 2    orlando           35
# 3  baltimore           38

# %%
df2=pd.DataFrame({
    "city":["chicago","new york","san diego"],
    "humidity":[65,68,75]
})
df2
# Out:
#         city  humidity
# 0    chicago        65
# 1   new york        68
# 2  san diego        75

# %%
pd.merge(df1,df2,on="city")
# Out:
#        city  temperature  humidity
# 0   chicago           21        65
# 1  new york           14        68

# %%
pd.merge(df1,df2,on="city",how="inner")
# Out:
#        city  temperature  humidity
# 0   chicago           21        65
# 1  new york           14        68

# %%
pd.merge(df1,df2,on="city",how="left")
# Out:
#         city  temperature  humidity
# 0    chicago           21      65.0
# 1   new york           14      68.0
# 2    orlando           35       NaN
# 3  baltimore           38       NaN

# %%
pd.merge(df1,df2,on="city",how="right")
# Out:
#         city  temperature  humidity
# 0    chicago         21.0        65
# 1   new york         14.0        68
# 2  san diego          NaN        75

# %%
pd.merge(df1,df2,on="city",how="outer")
# Out:
#         city  temperature  humidity
# 0  baltimore         38.0       NaN
# 1    chicago         21.0      65.0
# 2   new york         14.0      68.0
# 3    orlando         35.0       NaN
# 4  san diego          NaN      75.0

# %%
import pandas as pd

# %%
df_movies=pd.read_csv("D:\\personal\\Data Science\\7_concat_merge\\Exercise\\movies.csv")
df_movies
# Out:
#     movie_id                                        title   industry  \
# 0        101                             K.G.F: Chapter 2  Bollywood
# 1        102  Doctor Strange in the Multiverse of Madness  Hollywood
# 2        103                        Thor: The Dark World   Hollywood
# 3        104                              Thor: Ragnarok   Hollywood
# 4        105                      Thor: Love and Thunder   Hollywood
# 5        106                                       Sholay  Bollywood
# 6        107                  Dilwale Dulhania Le Jayenge  Bollywood
# 7        108                                     3 Idiots  Bollywood
# 8        109                     Kabhi Khushi Kabhie Gham  Bollywood
# 9        110                             Bajirao Mastani   Bollywood
# 10       111                     The Shawshank Redemption  Hollywood
# 11       112                                    Inception  Hollywood
# 12       113                                 Interstellar  Hollywood
# ...

# %%
df_financials=pd.read_csv("D:\\personal\Data Science\\7_concat_merge\\Exercise\\financials.csv")
df_financials
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\User\AppData\Local\Temp\ipykernel_22824\3855911522.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df_financials=pd.read_csv("D:\\personal\Data Science\\7_concat_merge\\Exercise\\financials.csv")
#     movie_id    budget   revenue       unit currency
# 0        101      1.00      12.5   Billions      INR
# 1        102    200.00     954.8   Millions      USD
# 2        103    165.00     644.8   Millions      USD
# 3        104    180.00     854.0   Millions      USD
# 4        105    250.00     670.0   Millions      USD
# 5        107    400.00    2000.0   Millions      INR
# 6        108    550.00    4000.0   Millions      INR
# 7        109    390.00    1360.0   Millions      INR
# 8        110      1.40       3.5   Billions      INR
# 9        111     25.00      73.3   Millions      USD
# 10       113    165.00     701.8   Millions      USD
# ...

# %%
df_languages=pd.read_csv("D:\\personal\\Data Science\\7_concat_merge\\Exercise\\languages.csv")
df_languages
# Out:
#    language_id lang_name
# 0            1     Hindi
# 1            2    Telugu
# 2            3   Kannada
# 3            4     Tamil
# 4            5   English
# 5            6    French
# 6            7   Bengali
# 7            8  Gujarati

# %%
df_movies.head(3)
# Out:
#    movie_id                                        title   industry  \
# 0       101                             K.G.F: Chapter 2  Bollywood
# 1       102  Doctor Strange in the Multiverse of Madness  Hollywood
# 2       103                        Thor: The Dark World   Hollywood
#
#    release_year  imdb_rating          studio  language_id
# 0          2022          8.4   Hombale Films            3
# 1          2022          7.0  Marvel Studios            5
# 2          2013          6.8  Marvel Studios            5

# %%
df_financials.head(3)
# Out:
#    movie_id  budget  revenue      unit currency
# 0       101     1.0     12.5  Billions      INR
# 1       102   200.0    954.8  Millions      USD
# 2       103   165.0    644.8  Millions      USD

# %%
df_languages.head(3)
# Out:
#    language_id lang_name
# 0            1     Hindi
# 1            2    Telugu
# 2            3   Kannada

# %%
df_new_movies=pd.read_csv("D:\\personal\\Data Science\\7_concat_merge\\Exercise\\new_movies.csv")
df_new_movies
# Out:
#    movie_id                           title   industry  release_year  \
# 0       201                         Pathaan  Bollywood          2023
# 1       210                          Vikram  Bollywood          2022
# 2       240  Black Panther: Wakanda Forever  Hollywood           200
#
#    imdb_rating                          studio  language_id
# 0          6.6                  Yash Raj Films            1
# 1          8.3  Raaj Kamal Films International            4
# 2          6.9                  Marvel Studios            5

# %%
df_movies=pd.concat([df_movies,df_new_movies],ignore_index=True)

# %%
df_movies
# Out:
#     movie_id                                        title   industry  \
# 0        101                             K.G.F: Chapter 2  Bollywood
# 1        102  Doctor Strange in the Multiverse of Madness  Hollywood
# 2        103                        Thor: The Dark World   Hollywood
# 3        104                              Thor: Ragnarok   Hollywood
# 4        105                      Thor: Love and Thunder   Hollywood
# 5        106                                       Sholay  Bollywood
# 6        107                  Dilwale Dulhania Le Jayenge  Bollywood
# 7        108                                     3 Idiots  Bollywood
# 8        109                     Kabhi Khushi Kabhie Gham  Bollywood
# 9        110                             Bajirao Mastani   Bollywood
# 10       111                     The Shawshank Redemption  Hollywood
# 11       112                                    Inception  Hollywood
# 12       113                                 Interstellar  Hollywood
# ...

# %%
df_movies.tail(5)
# Out:
#     movie_id                           title   industry  release_year  \
# 37       139                          Race 3  Bollywood          2018
# 38       140                       Shershaah  Bollywood          2021
# 39       201                         Pathaan  Bollywood          2023
# 40       210                          Vikram  Bollywood          2022
# 41       240  Black Panther: Wakanda Forever  Hollywood           200
#
#     imdb_rating                          studio  language_id
# 37          1.9               Salman Khan Films            1
# 38          8.4              Dharma Productions            1
# 39          6.6                  Yash Raj Films            1
# 40          8.3  Raaj Kamal Films International            4
# 41          6.9                  Marvel Studios            5

# %%
df_movies=pd.merge(df_movies,df_languages,on="language_id",how="inner")

# %%
df_movies
# Out:
#     movie_id                                        title   industry  \
# 0        101                             K.G.F: Chapter 2  Bollywood
# 1        102  Doctor Strange in the Multiverse of Madness  Hollywood
# 2        103                        Thor: The Dark World   Hollywood
# 3        104                              Thor: Ragnarok   Hollywood
# 4        105                      Thor: Love and Thunder   Hollywood
# 5        106                                       Sholay  Bollywood
# 6        107                  Dilwale Dulhania Le Jayenge  Bollywood
# 7        108                                     3 Idiots  Bollywood
# 8        109                     Kabhi Khushi Kabhie Gham  Bollywood
# 9        110                             Bajirao Mastani   Bollywood
# 10       111                     The Shawshank Redemption  Hollywood
# 11       112                                    Inception  Hollywood
# 12       113                                 Interstellar  Hollywood
# ...

# %%
df_movies=pd.merge(df_movies,df_financials,on="movie_id",how="left")

# %%
df_movies
# Out:
#     movie_id                                        title   industry  \
# 0        101                             K.G.F: Chapter 2  Bollywood
# 1        102  Doctor Strange in the Multiverse of Madness  Hollywood
# 2        103                        Thor: The Dark World   Hollywood
# 3        104                              Thor: Ragnarok   Hollywood
# 4        105                      Thor: Love and Thunder   Hollywood
# 5        106                                       Sholay  Bollywood
# 6        107                  Dilwale Dulhania Le Jayenge  Bollywood
# 7        108                                     3 Idiots  Bollywood
# 8        109                     Kabhi Khushi Kabhie Gham  Bollywood
# 9        110                             Bajirao Mastani   Bollywood
# 10       111                     The Shawshank Redemption  Hollywood
# 11       112                                    Inception  Hollywood
# 12       113                                 Interstellar  Hollywood
# ...

# %%
df_movies.tail(5)
# Out:
#     movie_id                           title   industry  release_year  \
# 37       139                          Race 3  Bollywood          2018
# 38       140                       Shershaah  Bollywood          2021
# 39       201                         Pathaan  Bollywood          2023
# 40       210                          Vikram  Bollywood          2022
# 41       240  Black Panther: Wakanda Forever  Hollywood           200
#
#     imdb_rating                          studio  language_id lang_name  \
# 37          1.9               Salman Khan Films            1     Hindi
# 38          8.4              Dharma Productions            1     Hindi
# 39          6.6                  Yash Raj Films            1     Hindi
# 40          8.3  Raaj Kamal Films International            4     Tamil
# 41          6.9                  Marvel Studios            5   English
#
#     budget  revenue      unit currency
# 37     1.8      3.1  Billions      INR
# ...

# %%
df_movies.to_csv("D:\\personal\\Data Science\\7_concat_merge\\Exercise\\final_complete_data.csv",columns=['movie_id', 'title', 'lang_name', 'budget', 'revenue', 'currency'],index=False)

# %%
df_movies
# Out:
#     movie_id                                        title   industry  \
# 0        101                             K.G.F: Chapter 2  Bollywood
# 1        102  Doctor Strange in the Multiverse of Madness  Hollywood
# 2        103                        Thor: The Dark World   Hollywood
# 3        104                              Thor: Ragnarok   Hollywood
# 4        105                      Thor: Love and Thunder   Hollywood
# 5        106                                       Sholay  Bollywood
# 6        107                  Dilwale Dulhania Le Jayenge  Bollywood
# 7        108                                     3 Idiots  Bollywood
# 8        109                     Kabhi Khushi Kabhie Gham  Bollywood
# 9        110                             Bajirao Mastani   Bollywood
# 10       111                     The Shawshank Redemption  Hollywood
# 11       112                                    Inception  Hollywood
# 12       113                                 Interstellar  Hollywood
# ...
