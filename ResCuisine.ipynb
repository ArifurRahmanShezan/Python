# %%
import numpy as np

# %%
import pandas as pd

# %%
df=pd.read_csv("D:\\personal\\Data Science\\practice\\Cuisine_rating.csv")

# %%
df
# Out:
#      User ID  Area code            Location  Gender   YOB Marital Status  \
# 0          1        153  Upper East Side,NY  Female  2006         Single
# 1          2        123       St. George,NY  Female  1991        Married
# 2          3        122  Upper West Side,NY    Male  1977         Single
# 3          4        153  Upper East Side,NY  Female  1956        Married
# 4          5        129     Central Park,NY    Male  1997         Single
# ..       ...        ...                 ...     ...   ...            ...
# 195      196        175       St. George,NY  Female  1982         Single
# 196      197        170  Upper West Side,NY  Female  2000        Married
# 197      198        160       St. George,NY  Female  2006         Single
# 198      199        130       St. George,NY    Male  2002        Married
# 199      200        140  Upper East Side,NY    Male  2005        Married
#
#          Activity  Budget  Cuisines  Alcohol     Smoker  Food Rating  \
# ...

# %%
df.shape
# Out:
# (200, 15)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      User ID  Area code            Location  Gender   YOB Marital Status  \
# 0          1        153  Upper East Side,NY  Female  2006         Single
# 1          2        123       St. George,NY  Female  1991        Married
# 2          3        122  Upper West Side,NY    Male  1977         Single
# 3          4        153  Upper East Side,NY  Female  1956        Married
# 4          5        129     Central Park,NY    Male  1997         Single
# ..       ...        ...                 ...     ...   ...            ...
# 195      196        175       St. George,NY  Female  1982         Single
# 196      197        170  Upper West Side,NY  Female  2000        Married
# 197      198        160       St. George,NY  Female  2006         Single
# 198      199        130       St. George,NY    Male  2002        Married
# 199      200        140  Upper East Side,NY    Male  2005        Married
#
# ...

# %%
df.isnull().count()
# Out:
# User ID           200
# Area code         200
# Location          200
# Gender            200
# YOB               200
# Marital Status    200
# Activity          200
# Budget            200
# Cuisines          200
# Alcohol           200
# Smoker            200
# Food Rating       200
# Service Rating    200
# Overall Rating    200
# Often A S         200
# dtype: int64

# %%
df.isnull().sum()
# Out:
# User ID           0
# Area code         0
# Location          0
# Gender            0
# YOB               0
# Marital Status    0
# Activity          0
# Budget            0
# Cuisines          0
# Alcohol           0
# Smoker            0
# Food Rating       0
# Service Rating    0
# Overall Rating    0
# Often A S         0
# dtype: int64

# %%
group_data=df.groupby("Cuisines")["Food Rating"].mean()

# %%
group_data
# Out:
# Cuisines
# Chinese     3.458333
# Filipino    2.705882
# French      3.294118
# Indian      2.781250
# Italian     3.222222
# Japanese    3.861111
# Seafood     3.227273
# Name: Food Rating, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   User ID         200 non-null    int64
#  1   Area code       200 non-null    int64
#  2   Location        200 non-null    object
#  3   Gender          200 non-null    object
#  4   YOB             200 non-null    int64
#  5   Marital Status  200 non-null    object
#  6   Activity        200 non-null    object
#  7   Budget          200 non-null    int64
#  8   Cuisines        200 non-null    object
#  9   Alcohol         200 non-null    object
#  10  Smoker          200 non-null    object
#  11  Food Rating     200 non-null    int64
#  12  Service Rating  200 non-null    int64
#  13  Overall Rating  200 non-null    float64
#  14  Often A S       200 non-null    object
# dtypes: float64(1), int64(6), object(8)
# memory usage: 23.6+ KB

# %%
df.replace({"Yes":True,"No":False})
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_16420\1485461345.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.replace({"Yes":True,"No":False})
#      User ID  Area code            Location  Gender   YOB Marital Status  \
# 0          1        153  Upper East Side,NY  Female  2006         Single
# 1          2        123       St. George,NY  Female  1991        Married
# 2          3        122  Upper West Side,NY    Male  1977         Single
# 3          4        153  Upper East Side,NY  Female  1956        Married
# 4          5        129     Central Park,NY    Male  1997         Single
# ..       ...        ...                 ...     ...   ...            ...
# 195      196        175       St. George,NY  Female  1982         Single
# ...

# %%
df
# Out:
#      User ID  Area code            Location  Gender   YOB Marital Status  \
# 0          1        153  Upper East Side,NY  Female  2006         Single
# 1          2        123       St. George,NY  Female  1991        Married
# 2          3        122  Upper West Side,NY    Male  1977         Single
# 3          4        153  Upper East Side,NY  Female  1956        Married
# 4          5        129     Central Park,NY    Male  1997         Single
# ..       ...        ...                 ...     ...   ...            ...
# 195      196        175       St. George,NY  Female  1982         Single
# 196      197        170  Upper West Side,NY  Female  2000        Married
# 197      198        160       St. George,NY  Female  2006         Single
# 198      199        130       St. George,NY    Male  2002        Married
# 199      200        140  Upper East Side,NY    Male  2005        Married
#
#          Activity  Budget  Cuisines  Alcohol     Smoker  Food Rating  \
# ...

# %%
df
# Out:
#      User ID  Area code            Location  Gender   YOB Marital Status  \
# 0          1        153  Upper East Side,NY  Female  2006         Single
# 1          2        123       St. George,NY  Female  1991        Married
# 2          3        122  Upper West Side,NY    Male  1977         Single
# 3          4        153  Upper East Side,NY  Female  1956        Married
# 4          5        129     Central Park,NY    Male  1997         Single
# ..       ...        ...                 ...     ...   ...            ...
# 195      196        175       St. George,NY  Female  1982         Single
# 196      197        170  Upper West Side,NY  Female  2000        Married
# 197      198        160       St. George,NY  Female  2006         Single
# 198      199        130       St. George,NY    Male  2002        Married
# 199      200        140  Upper East Side,NY    Male  2005        Married
#
#          Activity  Budget  Cuisines  Alcohol     Smoker  Food Rating  \
# ...

# %%
# Out:
#      User ID  Area code            Location  Gender   YOB Marital Status  \
# 0          1        153  Upper East Side,NY  Female  2006         Single
# 1          2        123       St. George,NY  Female  1991        Married
# 2          3        122  Upper West Side,NY    Male  1977         Single
# 3          4        153  Upper East Side,NY  Female  1956        Married
# 4          5        129     Central Park,NY    Male  1997         Single
# ..       ...        ...                 ...     ...   ...            ...
# 195      196        175       St. George,NY  Female  1982         Single
# 196      197        170  Upper West Side,NY  Female  2000        Married
# 197      198        160       St. George,NY  Female  2006         Single
# 198      199        130       St. George,NY    Male  2002        Married
# 199      200        140  Upper East Side,NY    Male  2005        Married
#
#          Activity  Budget  Cuisines  Alcohol     Smoker  Food Rating  \
# ...

# %%
df.groupby(["Gender","Cuisines"])["Overall Rating"].mean()
# Out:
# Gender  Cuisines
# Female  Chinese     3.321429
#         Filipino    3.291667
#         French      3.093750
#         Indian      3.150000
#         Italian     3.250000
#         Japanese    3.821429
#         Seafood     3.500000
# Male    Chinese     3.200000
#         Filipino    2.909091
#         French      3.111111
#         Indian      3.181818
#         Italian     3.083333
#         Japanese    3.454545
#         Seafood     3.055556
# Name: Overall Rating, dtype: float64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
group_data=df.groupby(["Location","Gender"])["Food Rating"].mean()

# %%
group_data
# Out:
# Location            Gender
# Cedar Hill, NY      Male      2.000000
# Central Park,NY     Female    4.000000
#                     Male      3.125000
# Central Park,ny     Female    2.000000
#                     Male      3.500000
# China Town, NY      Female    2.000000
#                     Male      2.833333
# Market City, MY     Male      4.000000
# Market City, NY     Female    3.750000
#                     Male      4.250000
# Riverdale,NY        Female    3.142857
#                     Male      2.928571
# St. George,NY       Female    3.722222
#                     Male      3.214286
# Upper East Side,NY  Female    3.222222
#                     Male      2.583333
# Upper West Side,NY  Female    3.000000
#                     Male      3.000000
# Name: Food Rating, dtype: float64

# %%
group_data=df.groupby(["Location","Gender"])["Food Rating"].mean().reset_index()

# %%
group_data
# Out:
#               Location  Gender  Food Rating
# 0       Cedar Hill, NY    Male     2.000000
# 1      Central Park,NY  Female     4.000000
# 2      Central Park,NY    Male     3.125000
# 3      Central Park,ny  Female     2.000000
# 4      Central Park,ny    Male     3.500000
# 5       China Town, NY  Female     2.000000
# 6       China Town, NY    Male     2.833333
# 7      Market City, MY    Male     4.000000
# 8      Market City, NY  Female     3.750000
# 9      Market City, NY    Male     4.250000
# 10        Riverdale,NY  Female     3.142857
# 11        Riverdale,NY    Male     2.928571
# 12       St. George,NY  Female     3.722222
# 13       St. George,NY    Male     3.214286
# 14  Upper East Side,NY  Female     3.222222
# 15  Upper East Side,NY    Male     2.583333
# 16  Upper West Side,NY  Female     3.000000
# 17  Upper West Side,NY    Male     3.000000

# %%
df.replace({"Central Park,ny":"Central Park,NY","Market City, MY":"Market City, NY"},inplace=True)

# %%
group_data1=df.groupby(["Cuisines","Gender"])["Food Rating"].mean().reset_index()
group_data
# Out:
#     Cuisines  Gender  Service Rating
# 0    Chinese  Female        3.214286
# 1    Chinese    Male        2.900000
# 2   Filipino  Female        3.333333
# 3   Filipino    Male        3.409091
# 4     French  Female        2.812500
# 5     French    Male        3.000000
# 6     Indian  Female        3.400000
# 7     Indian    Male        3.636364
# 8    Italian  Female        3.500000
# 9    Italian    Male        2.500000
# 10  Japanese  Female        3.571429
# 11  Japanese    Male        3.181818
# 12   Seafood  Female        4.500000
# 13   Seafood    Male        2.722222

# %%
plt.figure(figsize=(12,6))
sns.barplot(data=group_data1,x="Cuisines",y="Food Rating",hue="Gender")
plt.xticks(rotation=45)
plt.show()

# %%
group_data=df.groupby(["Cuisines","Gender"])["Service Rating"].mean().reset_index()

# %%
group_data
# Out:
#     Cuisines  Gender  Service Rating
# 0    Chinese  Female        3.214286
# 1    Chinese    Male        2.900000
# 2   Filipino  Female        3.333333
# 3   Filipino    Male        3.409091
# 4     French  Female        2.812500
# 5     French    Male        3.000000
# 6     Indian  Female        3.400000
# 7     Indian    Male        3.636364
# 8    Italian  Female        3.500000
# 9    Italian    Male        2.500000
# 10  Japanese  Female        3.571429
# 11  Japanese    Male        3.181818
# 12   Seafood  Female        4.500000
# 13   Seafood    Male        2.722222

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.barplot(data=group_data1,x="Cuisines",y="Food Rating",hue="Gender")
plt.title("Average Food Rating")
plt.xticks(rotation=45)
plt.subplot(1,2,2)
sns.barplot(data=group_data,x="Cuisines",y="Service Rating",hue="Gender")
plt.title("Average Service Rating")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
group_data2=df.groupby(["Marital Status","Activity"])["Overall Rating"].mean().reset_index()

# %%
group_data2
# Out:
#   Marital Status      Activity  Overall Rating
# 0       Divorced  Professional        4.250000
# 1       Divorced       Student        4.916667
# 2        Married  Professional        3.125000
# 3        Married       Student        2.690000
# 4         Single  Professional        3.583333
# 5         Single       Student        3.210938

# %%
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
sns.barplot(data=group_data1,x="Cuisines",y="Food Rating",hue="Gender")
plt.title("Average Food Rating")
plt.xticks(rotation=45)
plt.subplot(1,2,2)
sns.barplot(data=group_data,x="Cuisines",y="Service Rating",hue="Gender")
plt.title("Average Service Rating")
plt.xticks(rotation=45)
plt.subplot(1,2,3)
sns.barplot(data=group_data2,x="Marital Status",y="	Overall Rating",hue="Activity")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[104], line 10
#       8 plt.title("Average Service Rating")
#       9 plt.xticks(rotation=45)
# ---> 10 plt.subplot(1,2,3)
#      11 sns.barplot(data=group_data2,x="Marital Status",y="	Overall Rating",hue="Activity")
#      12 plt.tight_layout()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\matplotlib\pyplot.py:1534, in subplot(*args, **kwargs)
#    1531 fig = gcf()
#    1533 # First, search for an existing subplot with a matching spec.
# -> 1534 key = SubplotSpec._from_subplot_args(fig, args)
#    1536 for ax in fig.axes:
#    1537     # If we found an Axes at the position, we can reuse it if the user passed no
#    1538     # kwargs or if the Axes class and kwargs are identical.
#    1539     if (ax.get_subplotspec() == key
#    1540         and (kwargs == {}
# ...

# %%
sns.barplot(data=group_data2,x="Marital Status",y="Overall Rating",hue="Activity")
plt.tight_layout()
plt.show()

# %%
group_marital_fd=df.groupby(["Marital Status"])["Food Rating"].mean().reset_index()

# %%
group_marital_fd
# Out:
#   Marital Status  Food Rating
# 0       Divorced     4.642857
# 1        Married     2.697674
# 2         Single     3.470000

# %%
group_marital_sr=df.groupby(["Marital Status"])["Service Rating"].mean().reset_index()

# %%
group_marital_sr
# Out:
#   Marital Status  Service Rating
# 0       Divorced        4.428571
# 1        Married        3.046512
# 2         Single        3.220000

# %%
group_marital_or=df.groupby(["Marital Status"])["Overall Rating"].mean().reset_index()

# %%
group_marital_or
# Out:
#   Marital Status  Overall Rating
# 0       Divorced        4.535714
# 1        Married        2.872093
# 2         Single        3.345000

# %%
group_profession_fd=df.groupby(["Activity"])["Food Rating"].mean().reset_index()

# %%
group_profession_fd
# Out:
#        Activity  Food Rating
# 0  Professional     3.387500
# 1       Student     3.108333

# %%
group_profession_sr=df.groupby(["Activity"])["Service Rating"].mean().reset_index()

# %%
group_profession_sr
# Out:
#        Activity  Service Rating
# 0  Professional            3.50
# 1       Student            3.05

# %%
group_profession_or=df.groupby(["Activity"])["Overall Rating"].mean().reset_index()

# %%
group_profession_or
# Out:
#        Activity  Overall Rating
# 0  Professional        3.443750
# 1       Student        3.079167

# %%
plt.figure(figsize=(12,6))
plt.subplot(2,3,1)
sns.barplot(data=group_marital_fd,x="Marital Status",y="Food Rating")
plt.subplot(2,3,2)
sns.barplot(data=group_marital_sr,x="Marital Status",y="Service Rating")
plt.subplot(2,3,3)
sns.barplot(data=group_marital_or,x="Marital Status",y="Overall Rating")
plt.subplot(2,3,4)
sns.barplot(data=group_profession_fd,x="Activity",y="Food Rating")
plt.subplot(2,3,5)
sns.barplot(data=group_profession_sr,x="Activity",y="Service Rating")
plt.subplot(2,3,6)
sns.barplot(data=group_profession_or,x="Activity",y="Overall Rating")
plt.tight_layout()
plt.show()

# %%
counts=df["Marital Status"].value_counts()
plt.figure(figsize=(6,6))
plt.pie(counts,labels=counts.index,autopct="%1.1f%%",startangle=90,explode=(0,0,0.1))
plt.title("proportion of marital status")
plt.show()

# %%
counts=df["Activity"].value_counts()
plt.figure(figsize=(6,6))
plt.pie(counts,labels=counts.index,autopct="%1.1f%%",startangle=90,explode=(0.1,0),shadow=True)
plt.title("proportion of Activity")
plt.legend()
plt.show()
